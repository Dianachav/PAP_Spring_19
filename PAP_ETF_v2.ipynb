# %%
# Librerias
import quandl
import datetime
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://www.carrerasenlinea.mx/logos/original/logo-instituto-tecnologico-y-de-estudios-superiores-de-occidente.png" width="150px" height="100px" />
#
# # Proyecto de Aplicación Profesional
#
# ## Optimización De Programas de Inversión para Intermediarios Financieros
#
#
#
# ### Integrantes:
#
# ### - Jazmín Calderón
# ### - Diana Chávez
# ### - Juan Antonio Flores

# %%
#Lista de nombres de los 36 ETF's

lista = ['1-3-Year-Treasury-Bond',
         '20-Year-Treasury-Bond',
         '7-10-Year-Treasury-Bond',
         'Core-MSCI-EAFE',
         'Core-MSCI-Emerging-Markets',
         'Core-MSCI-Total-International-Stock',
         'Core-SP-500',
         'Core-SP-Mid-Cap', 
         'Core-SP-Small-Cap',
         'Core-SP-Total-US-Stock-Market',
         'Core-US-Aggregate-Bond',
         'Edge-MSCI-Min-Vol-EAFE', 
         'Edge-MSCI-Min-Vol-USA',
         'Edge-MSCI-USA-Quality-Factor',
         'Floating-Rate-Bond',
         'JP-Morgan-USD-Emerging-Markets-Bond', 
         'MBS',
         'MSCI-ACWI',
         'MSCI-EAFE',
         'MSCI-Emerging-Markets',
         'MSCI-Japan',
         'Nasdaq-Biotechnology',
         'Preferred-and-Income-Securities',
         'Russell-1000',
         'Russell-1000-Growth',
         'Russell-1000-Value',
         'Russell-2000',
         'Russell-3000',
         'SP-500-Growth',
         'SP-500-Value',
         'Select-Dividend',
         'Short-Term-Corporate-Bond',
         'Short-Treasury-Bond',
         'TIPS-Bond',
         'iBoxx--High-Yield-Corporate-Bond',
         'iBoxx--Investment-Grade-Corporate-Bond']

# Todos tienen en común:

#'https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-
# +
# NOMBRE ETF EN LISTA
# +
# -ETF_fund.csv',

# %% [markdown]
# ## Importar Datos

# %% [markdown]
# ## ETF'S

# %%
#Leer archivos .csv
ETF = pd.read_csv('https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-1-3-Year-Treasury-Bond-ETF_fund.csv',
                  skiprows = [0,1,2,3], delim_whitespace=False)

#Limpieza y acondicionamiento del DataFrame
ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].replace('--',0)
ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].astype(float)

#Obtención de rendimiento promedio mensual y desviación estándar mensual
rend_men = ETF['Rendimientos mensual']
desv = np.std(rend_men)
rend = np.mean(rend_men)
desv, rend
# Out:
# (0.37086061734835124, 0.15905)

# %%
ETF = pd.read_csv('https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-20-Year-Treasury-Bond-ETF_fund.csv',
                  skiprows = [0,1,2,3], delim_whitespace=False)
ETF
# Out:
#     Fecha a fin de mes Rendimientos mensual
# 0          31-jul-2002                   --
# 1          31-ago-2002                 5.21
# 2          30-sep-2002                 4.43
# 3          31-oct-2002                -3.74
# 4          30-nov-2002                -0.83
# 5          31-dic-2002                 4.33
# 6          31-ene-2003                -0.31
# 7          28-feb-2003                 3.15
# 8          31-mar-2003                -1.67
# 9          30-abr-2003                 1.27
# 10         31-may-2003                 6.38
# 11         30-jun-2003                -2.03
# 12         31-jul-2003               -10.31
# 13         31-ago-2003                 2.14
# 14         30-sep-2003                 5.57
# 15         31-oct-2003                -3.11
# 16         30-nov-2003                 0.56
# 17         31-dic-2003                 1.20
# 18         31-ene-2004                 1.99
# 19         29-feb-2004                 2.17
# 20         31-mar-2004                 1.53
# 21         30-abr-2004                -6.23
# 22         31-may-2004                -0.48
# 23         30-jun-2004                 1.01
# 24         31-jul-2004                 1.81
# 25         31-ago-2004                 4.13
# 26         30-sep-2004                 1.08
# 27         31-oct-2004                 1.66
# 28         30-nov-2004                -2.46
# 29         31-dic-2004                 2.76
# ..                 ...                  ...
# 170        30-sep-2016                -1.77
# 171        31-oct-2016                -4.27
# 172        30-nov-2016                -7.70
# 173        31-dic-2016                -0.58
# 174        31-ene-2017                 0.41
# 175        28-feb-2017                 1.61
# 176        31-mar-2017                -0.59
# 177        30-abr-2017                 1.55
# 178        31-may-2017                 2.09
# 179        30-jun-2017                 0.47
# 180        31-jul-2017                -0.71
# 181        31-ago-2017                 3.60
# 182        30-sep-2017                -2.26
# 183        31-oct-2017                -0.05
# 184        30-nov-2017                 0.79
# 185        31-dic-2017                 1.80
# 186        31-ene-2018                -3.28
# 187        28-feb-2018                -3.11
# 188        31-mar-2018                 3.11
# 189        30-abr-2018                -1.96
# 190        31-may-2018                 2.20
# 191        30-jun-2018                 0.21
# 192        31-jul-2018                -1.58
# 193        31-ago-2018                 1.60
# 194        30-sep-2018                -3.08
# 195        31-oct-2018                -3.19
# 196        30-nov-2018                 1.88
# 197        31-dic-2018                 5.61
# 198        31-ene-2019                 0.62
# 199        28-feb-2019                -1.26
#
# [200 rows x 2 columns]

# %%
print (lista[1])
# Out:
# 20-Year-Treasury-Bond

# %%
#ETF = pd.read_csv('https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-1-3-Year-Treasury-Bond-ETF_fund.csv',
 #                 skiprows = [0,1,2,3], delim_whitespace=False)
desv=[]
rend = []
for i in range(36):
    a='https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-'
    b='-ETF_fund.csv'
    dd=[]
    ETF = pd.read_csv(a+lista[i]+b,skiprows = [0,1,2,3], delim_whitespace=False)
    
    #Limpieza y acondicionamiento del DataFrame
    ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].replace('--',0)
    ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].astype(float)
    
    #Obtención de rendimiento promedio mensual y desviación estándar mensual
    rend_men = ETF['Rendimientos mensual']
    
    desv.append(np.std(rend_men))
    rend.append(np.mean(rend_men))
    

    
    
    
      
print(desv,rend)
# Out:
# [0.37086061734835124, 3.641023811718346, 1.8200154937527318, 3.4130303768816086, 4.136979252441616, 3.400637410115205, 4.1629555671842535, 4.843601250055936, 5.305553238080959, 3.9760451207902663, 0.9264002379401627, 2.79845063721755, 2.5105222976090196, 3.156260297526798, 0.22627008214775807, 2.5909869313571705, 0.7415708297423054, 4.75908067541566, 4.728961956302914, 6.058855767762592, 4.971738108062902, 6.637201085301265, 5.010471388397563, 4.230855892734813, 4.760771620749666, 4.138093642162665, 5.5218567337021955, 4.28731262286718, 4.267103530148253, 4.382236455342916, 3.80512043047655, 0.5963183040938248, 0.13525945821213986, 1.629547805480063, 2.9111667738104847, 1.8795384745995487] [0.15905, 0.5589500000000003, 0.3814499999999996, 0.5905194805194806, 0.3511688311688313, 0.5023376623376624, 0.5344690265486727, 0.842964601769912, 0.9342035398230086, 0.7526373626373629, 0.305268817204301, 0.6446067415730341, 1.1062921348314605, 1.0005882352941173, 0.10397849462365588, 0.5025925925925927, 0.2856944444444445, 0.5556060606060605, 0.5341706161137437, 1.0119895287958112, 0.15884057971014495, 0.8142396313364055, 0.45527777777777767, 0.560088495575221, 0.478230088495575, 0.6182300884955753, 0.7919911504424778, 0.5701769911504425, 0.5130530973451323, 0.5544247787610618, 0.7205978260869565, 0.22102739726027398, 0.07657534246575341, 0.31393442622950823, 0.47461538461538466, 0.4478500000000004]

# %%
n_etf=[]
for i in range(36):
    n_etf.append(1+i)
#print(n_etf)

# %%
tabla = pd.DataFrame(index=n_etf,columns=['Rend %','Riesgo'])
tabla.index.name = "ETF"
tabla['Rend %'] = rend
tabla['Riesgo'] = desv

tabla
# Out:
#        Rend %    Riesgo
# ETF
# 1    0.159050  0.370861
# 2    0.558950  3.641024
# 3    0.381450  1.820015
# 4    0.590519  3.413030
# 5    0.351169  4.136979
# 6    0.502338  3.400637
# 7    0.534469  4.162956
# 8    0.842965  4.843601
# 9    0.934204  5.305553
# 10   0.752637  3.976045
# 11   0.305269  0.926400
# 12   0.644607  2.798451
# 13   1.106292  2.510522
# 14   1.000588  3.156260
# 15   0.103978  0.226270
# 16   0.502593  2.590987
# 17   0.285694  0.741571
# 18   0.555606  4.759081
# 19   0.534171  4.728962
# 20   1.011990  6.058856
# 21   0.158841  4.971738
# 22   0.814240  6.637201
# 23   0.455278  5.010471
# 24   0.560088  4.230856
# 25   0.478230  4.760772
# 26   0.618230  4.138094
# 27   0.791991  5.521857
# 28   0.570177  4.287313
# 29   0.513053  4.267104
# 30   0.554425  4.382236
# 31   0.720598  3.805120
# 32   0.221027  0.596318
# 33   0.076575  0.135259
# 34   0.313934  1.629548
# 35   0.474615  2.911167
# 36   0.447850  1.879538

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import numpy as np
import plotly

# %%
plotly.tools.set_credentials_file(username='jazerape', api_key='eX7PWHChSnlXoCQOaddE')

# %%
z = rend
z_text = np.around(z, decimals=2) # Only show rounded value (full value on hover)

z
# Out:
# [0.15905,
#  0.5589500000000003,
#  0.3814499999999996,
#  0.5905194805194806,
#  0.3511688311688313,
#  0.5023376623376624,
#  0.5344690265486727,
#  0.842964601769912,
#  0.9342035398230086,
#  0.7526373626373629,
#  0.305268817204301,
#  0.6446067415730341,
#  1.1062921348314605,
#  1.0005882352941173,
#  0.10397849462365588,
#  0.5025925925925927,
#  0.2856944444444445,
#  0.5556060606060605,
#  0.5341706161137437,
#  1.0119895287958112,
#  0.15884057971014495,
#  0.8142396313364055,
#  0.45527777777777767,
#  0.560088495575221,
#  0.478230088495575,
#  0.6182300884955753,
#  0.7919911504424778,
#  0.5701769911504425,
#  0.5130530973451323,
#  0.5544247787610618,
#  0.7205978260869565,
#  0.22102739726027398,
#  0.07657534246575341,
#  0.31393442622950823,
#  0.47461538461538466,
#  0.4478500000000004]

# %%
colorscale = [[0, '#66475e'], [1, '#ecbfe0']]
fig = ff.create_annotated_heatmap(z, annotation_text=z_text, colorscale=colorscale, hoverinfo='z')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-5fea7c884d0a> in <module>()
#       1 colorscale = [[0, '#66475e'], [1, '#ecbfe0']]
# ----> 2 fig = ff.create_annotated_heatmap(z, annotation_text=z_text, colorscale=colorscale, hoverinfo='z')
#       3
#
# ~\Anaconda3\intento de instalar\lib\site-packages\plotly\figure_factory\_annotated_heatmap.py in create_annotated_heatmap(z, x, y, annotation_text, colorscale, font_colors, showscale, reversescale, **kwargs)
#      89     annotations = _AnnotatedHeatmap(z, x, y, annotation_text,
#      90                                     colorscale, font_colors, reversescale,
# ---> 91                                     **kwargs).make_annotations()
#      92
#      93     if x or y:
#
# ~\Anaconda3\intento de instalar\lib\site-packages\plotly\figure_factory\_annotated_heatmap.py in __init__(self, z, x, y, annotation_text, colorscale, font_colors, reversescale, **kwargs)
#     124             self.x = x
#     125         else:
# --> 126             self.x = range(len(z[0]))
#     127         if y:
#     128             self.y = y
#
# TypeError: object of type 'float' has no len()

# %%
# Make text size smaller
for i in range(len(fig.layout.annotations)):
    fig.layout.annotations[i].font.size = 8

# %%
py.iplot(fig, filename='annotated_heatmap_numpy')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jazerape/24.embed" height="525px" width="100%"></iframe>
