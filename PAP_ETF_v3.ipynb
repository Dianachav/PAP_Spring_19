# %%
# Librerias
import quandl
import datetime
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://www.carrerasenlinea.mx/logos/original/logo-instituto-tecnologico-y-de-estudios-superiores-de-occidente.png" width="150px" height="100px" />
#
# # Proyecto de Aplicación Profesional
#
# ## Optimización De Programas de Inversión para Intermediarios Financieros
#
#
#
# ### Integrantes:
#
# ### - Jazmín Calderón
# ### - Diana Chávez
# ### - Juan Antonio Flores

# %%
#Lista de nombres de los 36 ETF's

lista = ['1-3-Year-Treasury-Bond',
         '20-Year-Treasury-Bond',
         '7-10-Year-Treasury-Bond',
         'Core-MSCI-EAFE',
         'Core-MSCI-Emerging-Markets',
         'Core-MSCI-Total-International-Stock',
         'Core-SP-500',
         'Core-SP-Mid-Cap', 
         'Core-SP-Small-Cap',
         'Core-SP-Total-US-Stock-Market',
         'Core-US-Aggregate-Bond',
         'Edge-MSCI-Min-Vol-EAFE', 
         'Edge-MSCI-Min-Vol-USA',
         'Edge-MSCI-USA-Quality-Factor',
         'Floating-Rate-Bond',
         'JP-Morgan-USD-Emerging-Markets-Bond', 
         'MBS',
         'MSCI-ACWI',
         'MSCI-EAFE',
         'MSCI-Emerging-Markets',
         'MSCI-Japan',
         'Nasdaq-Biotechnology',
         'Preferred-and-Income-Securities',
         'Russell-1000',
         'Russell-1000-Growth',
         'Russell-1000-Value',
         'Russell-2000',
         'Russell-3000',
         'SP-500-Growth',
         'SP-500-Value',
         'Select-Dividend',
         'Short-Term-Corporate-Bond',
         'Short-Treasury-Bond',
         'TIPS-Bond',
         'iBoxx--High-Yield-Corporate-Bond',
         'iBoxx--Investment-Grade-Corporate-Bond']

# Todos tienen en común:

#'https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-
# +
# NOMBRE ETF EN LISTA
# +
# -ETF_fund.csv',

# %% [markdown]
# ## Importar Datos

# %% [markdown]
# ## ETF'S

# %%
#Leer archivos .csv
ETF = pd.read_csv('https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-1-3-Year-Treasury-Bond-ETF_fund.csv',
                  skiprows = [0,1,2,3], delim_whitespace=False)

#Limpieza y acondicionamiento del DataFrame
ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].replace('--',0)
ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].astype(float)

#Obtención de rendimiento promedio mensual y desviación estándar mensual
rend_men = ETF['Rendimientos mensual']
desv = np.std(rend_men)
rend = np.mean(rend_men)
desv, rend
# Out:
# (0.37086061734835124, 0.15905)

# %%
#ETF = pd.read_csv('https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-1-3-Year-Treasury-Bond-ETF_fund.csv',
 #                 skiprows = [0,1,2,3], delim_whitespace=False)
desv=[]
rend = []
for i in range(36):
    a='https://raw.githubusercontent.com/Dianachav/PAP_Spring_19/master/ETFS/iShares-'
    b='-ETF_fund.csv'
    dd=[]
    ETF = pd.read_csv(a+lista[i]+b,skiprows = [0,1,2,3], delim_whitespace=False)
    
    #Limpieza y acondicionamiento del DataFrame
    ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].replace('--',0)
    ETF['Rendimientos mensual'] = ETF['Rendimientos mensual'].astype(float)
    
    #Obtención de rendimiento promedio mensual y desviación estándar mensual
    rend_men = ETF['Rendimientos mensual']
    
    desv.append(np.std(rend_men))
    rend.append(np.mean(rend_men))
    

    
    
    
      
print(desv,rend)
# Out:
# [0.37086061734835124, 3.641023811718346, 1.8200154937527318, 3.4130303768816086, 4.136979252441616, 3.400637410115205, 4.1629555671842535, 4.843601250055936, 5.305553238080959, 3.9760451207902663, 0.9264002379401627, 2.79845063721755, 2.5105222976090196, 3.156260297526798, 0.22627008214775807, 2.5909869313571705, 0.7415708297423054, 4.75908067541566, 4.728961956302914, 6.058855767762592, 4.971738108062902, 6.637201085301265, 5.010471388397563, 4.230855892734813, 4.760771620749666, 4.138093642162665, 5.5218567337021955, 4.28731262286718, 4.267103530148253, 4.382236455342916, 3.80512043047655, 0.5963183040938248, 0.13525945821213986, 1.629547805480063, 2.9111667738104847, 1.8795384745995487] [0.15905, 0.5589500000000003, 0.3814499999999996, 0.5905194805194806, 0.3511688311688313, 0.5023376623376624, 0.5344690265486727, 0.842964601769912, 0.9342035398230086, 0.7526373626373629, 0.305268817204301, 0.6446067415730341, 1.1062921348314605, 1.0005882352941173, 0.10397849462365588, 0.5025925925925927, 0.2856944444444445, 0.5556060606060605, 0.5341706161137437, 1.0119895287958112, 0.15884057971014495, 0.8142396313364055, 0.45527777777777767, 0.560088495575221, 0.478230088495575, 0.6182300884955753, 0.7919911504424778, 0.5701769911504425, 0.5130530973451323, 0.5544247787610618, 0.7205978260869565, 0.22102739726027398, 0.07657534246575341, 0.31393442622950823, 0.47461538461538466, 0.4478500000000004]

# %%
n_etf=[]
for i in range(36):
    n_etf.append(1+i)
#print(n_etf)

# %%
tabla = pd.DataFrame(index=lista,columns=['Rend %','Riesgo'])
tabla.index.name = "ETF"
tabla['Rend %'] = rend
tabla['Riesgo'] = desv

tabla
# Out:
#                                           Rend %    Riesgo
# ETF
# 1-3-Year-Treasury-Bond                  0.159050  0.370861
# 20-Year-Treasury-Bond                   0.558950  3.641024
# 7-10-Year-Treasury-Bond                 0.381450  1.820015
# Core-MSCI-EAFE                          0.590519  3.413030
# Core-MSCI-Emerging-Markets              0.351169  4.136979
# Core-MSCI-Total-International-Stock     0.502338  3.400637
# Core-SP-500                             0.534469  4.162956
# Core-SP-Mid-Cap                         0.842965  4.843601
# Core-SP-Small-Cap                       0.934204  5.305553
# Core-SP-Total-US-Stock-Market           0.752637  3.976045
# Core-US-Aggregate-Bond                  0.305269  0.926400
# Edge-MSCI-Min-Vol-EAFE                  0.644607  2.798451
# Edge-MSCI-Min-Vol-USA                   1.106292  2.510522
# Edge-MSCI-USA-Quality-Factor            1.000588  3.156260
# Floating-Rate-Bond                      0.103978  0.226270
# JP-Morgan-USD-Emerging-Markets-Bond     0.502593  2.590987
# MBS                                     0.285694  0.741571
# MSCI-ACWI                               0.555606  4.759081
# MSCI-EAFE                               0.534171  4.728962
# MSCI-Emerging-Markets                   1.011990  6.058856
# MSCI-Japan                              0.158841  4.971738
# Nasdaq-Biotechnology                    0.814240  6.637201
# Preferred-and-Income-Securities         0.455278  5.010471
# Russell-1000                            0.560088  4.230856
# Russell-1000-Growth                     0.478230  4.760772
# Russell-1000-Value                      0.618230  4.138094
# Russell-2000                            0.791991  5.521857
# Russell-3000                            0.570177  4.287313
# SP-500-Growth                           0.513053  4.267104
# SP-500-Value                            0.554425  4.382236
# Select-Dividend                         0.720598  3.805120
# Short-Term-Corporate-Bond               0.221027  0.596318
# Short-Treasury-Bond                     0.076575  0.135259
# TIPS-Bond                               0.313934  1.629548
# iBoxx--High-Yield-Corporate-Bond        0.474615  2.911167
# iBoxx--Investment-Grade-Corporate-Bond  0.447850  1.879538

# %% [markdown]
# ### Mapa de calor

# %%
uno=rend[0:6]
dos=rend[6:12]
tres=rend[12:18]
cuatro=rend[18:24]
cinco=rend[24:30]
seis=rend[30:36]

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import numpy as np
import plotly

# %%
plotly.tools.set_credentials_file(username='jazerape', api_key='eX7PWHChSnlXoCQOaddE')

# %%
z = [uno,dos,tres,cuatro,cinco,seis]

# %%
unot=lista[0:6]
dost=lista[6:12]
trest=lista[12:18]
cuatrot=lista[18:24]
cincot=lista[24:30]
seist=lista[30:36]

# %%
z_text = [unot,dost,trest,cuatrot,cincot,seist]

# %%
#z=rend
#z = np.random.randn(20, 20)
z_text = np.around(z, decimals=2) # Only show rounded value (full value on hover)

#z

# %%
colorscale = [[0, '#66475e'], [1, '#ecbfe0']]
fig = ff.create_annotated_heatmap(z, annotation_text=z_text, colorscale=colorscale, hoverinfo='z')

# %%
# Make text size smaller
for i in range(len(fig.layout.annotations)):
    fig.layout.annotations[i].font.size = 8

# %%
py.iplot(fig, filename='annotated_heatmap_numpy')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jazerape/24.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Medidas de Atribución al desempeño

# %%
# Out:
# 4.136979252441616

# %%
usd_rate = [0.0241,0.0241,0.0239,0.0240,0.0241,0.0241,0.0243,0.0243,0.0242,0.0242,0.0241,
           0.0241,0.0241,0.0239,0.0240,0.0241,0.0241,0.0243,0.0243,0.0242,0.0242,0.0241,
           0.0241,0.0241,0.0239,0.0240,0.0241,0.0241,0.0243,0.0243,0.0242,0.0242,0.0241,
           0.0241,0.0241,0.0239] #tasa libre de riesgo EEUU #0.0241
sharpe_ETF=[]
for i in range(36):
    #sharpe[i] = (rend[i]-usd_rate[i])/desv[i]
    sharpe_ETF.append((rend[i]-usd_rate[i])/desv[i])
print(sharpe_ETF)
# Out:
# [0.3638833396894251, 0.14689549633776852, 0.19645437152996928, 0.16598723654991132, 0.07905981906382478, 0.14063177124239803, 0.12254971697758034, 0.16901981800431193, 0.1715190667188858, 0.18320651313247194, 0.3035068490801295, 0.22173224473596323, 0.431062546571334, 0.309444767929767, 0.3534647349950075, 0.18467580318591423, 0.3527571931805194, 0.11164048202642753, 0.10781871810877472, 0.16303235572161195, 0.02708118906983294, 0.11904711356210791, 0.08605533179497427, 0.1266855948687866, 0.09543202755523755, 0.14359996169275102, 0.13906393944553427, 0.12737046238192176, 0.11453977947616177, 0.1209712858179349, 0.18301597513425882, 0.3300710307046103, 0.3879606140625782, 0.17786187386145652, 0.15475423416766193, 0.22556069254731617]

# %%
# Treynor
beta = [0.0241,0.0241,0.0239,0.0240,0.0241,0.0241,0.0243,0.0243,0.0242,0.0242,0.0241,
           0.0241,0.0241,0.0239,0.0240,0.0241,0.0241,0.0243,0.0243,0.0242,0.0242,0.0241,
           0.0241,0.0241,0.0239,0.0240,0.0241,0.0241,0.0243,0.0243,0.0242,0.0242,0.0241,
           0.0241,0.0241,0.0239]

treynor_ETF=[]
for i in range(36):
    #sharpe[i] = (rend[i]-usd_rate[i])/desv[i]
    treynor_ETF.append((rend[i]-usd_rate[i])/beta[i])
print(treynor_ETF)
# Out:
# [5.5995850622406635, 22.192946058091298, 14.960251046025089, 23.604978354978353, 13.57132079538719, 19.84388640405238, 20.994610146035914, 33.68990130740379, 37.60345205880201, 30.100717464353842, 11.666755900593401, 25.747167700125896, 44.90423795981164, 40.86561653950282, 3.332437275985662, 19.85446442292916, 10.854541263254957, 21.864446938521013, 20.98232988122402, 40.81774912379385, 5.563660318601031, 32.785876818937986, 17.891194098662975, 22.240186538390912, 19.00962713370607, 24.75958702064897, 31.86270333786215, 22.65879631329637, 20.113296187042483, 21.815834516916123, 28.776769673014734, 8.133363523151818, 2.17740010231342, 12.026324739813619, 18.69358442387488, 17.73849372384939]

# %%
tabla = pd.DataFrame(index=lista,columns=['Rend %','Riesgo','Sharpe','Treynor %'])
tabla.index.name = "ETF"
tabla['Rend %'] = rend
tabla['Riesgo'] = desv
tabla['Sharpe'] = sharpe_ETF
tabla['Treynor %'] = treynor_ETF
tabla
# Out:
#                                           Rend %    Riesgo    Sharpe  \
# ETF
# 1-3-Year-Treasury-Bond                  0.159050  0.370861  0.363883
# 20-Year-Treasury-Bond                   0.558950  3.641024  0.146895
# 7-10-Year-Treasury-Bond                 0.381450  1.820015  0.196454
# Core-MSCI-EAFE                          0.590519  3.413030  0.165987
# Core-MSCI-Emerging-Markets              0.351169  4.136979  0.079060
# Core-MSCI-Total-International-Stock     0.502338  3.400637  0.140632
# Core-SP-500                             0.534469  4.162956  0.122550
# Core-SP-Mid-Cap                         0.842965  4.843601  0.169020
# Core-SP-Small-Cap                       0.934204  5.305553  0.171519
# Core-SP-Total-US-Stock-Market           0.752637  3.976045  0.183207
# Core-US-Aggregate-Bond                  0.305269  0.926400  0.303507
# Edge-MSCI-Min-Vol-EAFE                  0.644607  2.798451  0.221732
# Edge-MSCI-Min-Vol-USA                   1.106292  2.510522  0.431063
# Edge-MSCI-USA-Quality-Factor            1.000588  3.156260  0.309445
# Floating-Rate-Bond                      0.103978  0.226270  0.353465
# JP-Morgan-USD-Emerging-Markets-Bond     0.502593  2.590987  0.184676
# MBS                                     0.285694  0.741571  0.352757
# MSCI-ACWI                               0.555606  4.759081  0.111640
# MSCI-EAFE                               0.534171  4.728962  0.107819
# MSCI-Emerging-Markets                   1.011990  6.058856  0.163032
# MSCI-Japan                              0.158841  4.971738  0.027081
# Nasdaq-Biotechnology                    0.814240  6.637201  0.119047
# Preferred-and-Income-Securities         0.455278  5.010471  0.086055
# Russell-1000                            0.560088  4.230856  0.126686
# Russell-1000-Growth                     0.478230  4.760772  0.095432
# Russell-1000-Value                      0.618230  4.138094  0.143600
# Russell-2000                            0.791991  5.521857  0.139064
# Russell-3000                            0.570177  4.287313  0.127370
# SP-500-Growth                           0.513053  4.267104  0.114540
# SP-500-Value                            0.554425  4.382236  0.120971
# Select-Dividend                         0.720598  3.805120  0.183016
# Short-Term-Corporate-Bond               0.221027  0.596318  0.330071
# Short-Treasury-Bond                     0.076575  0.135259  0.387961
# TIPS-Bond                               0.313934  1.629548  0.177862
# iBoxx--High-Yield-Corporate-Bond        0.474615  2.911167  0.154754
# iBoxx--Investment-Grade-Corporate-Bond  0.447850  1.879538  0.225561
#
#                                         Treynor %
# ETF
# 1-3-Year-Treasury-Bond                   5.599585
# 20-Year-Treasury-Bond                   22.192946
# 7-10-Year-Treasury-Bond                 14.960251
# Core-MSCI-EAFE                          23.604978
# Core-MSCI-Emerging-Markets              13.571321
# Core-MSCI-Total-International-Stock     19.843886
# Core-SP-500                             20.994610
# Core-SP-Mid-Cap                         33.689901
# Core-SP-Small-Cap                       37.603452
# Core-SP-Total-US-Stock-Market           30.100717
# Core-US-Aggregate-Bond                  11.666756
# Edge-MSCI-Min-Vol-EAFE                  25.747168
# Edge-MSCI-Min-Vol-USA                   44.904238
# Edge-MSCI-USA-Quality-Factor            40.865617
# Floating-Rate-Bond                       3.332437
# JP-Morgan-USD-Emerging-Markets-Bond     19.854464
# MBS                                     10.854541
# MSCI-ACWI                               21.864447
# MSCI-EAFE                               20.982330
# MSCI-Emerging-Markets                   40.817749
# MSCI-Japan                               5.563660
# Nasdaq-Biotechnology                    32.785877
# Preferred-and-Income-Securities         17.891194
# Russell-1000                            22.240187
# Russell-1000-Growth                     19.009627
# Russell-1000-Value                      24.759587
# Russell-2000                            31.862703
# Russell-3000                            22.658796
# SP-500-Growth                           20.113296
# SP-500-Value                            21.815835
# Select-Dividend                         28.776770
# Short-Term-Corporate-Bond                8.133364
# Short-Treasury-Bond                      2.177400
# TIPS-Bond                               12.026325
# iBoxx--High-Yield-Corporate-Bond        18.693584
# iBoxx--Investment-Grade-Corporate-Bond  17.738494
